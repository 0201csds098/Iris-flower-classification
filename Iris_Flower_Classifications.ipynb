# %% [markdown]
# <a href="https://colab.research.google.com/github/0201csds098/OIBSIP_task_1/blob/main/Iris_Flower_Classifications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd/content/gdrive/My Drive/Colab Notebooks/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
df = pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df=df.drop(columns=[])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.shape
# Out:
# (150, 6)

# %%
df["Species"].replace({"Iris.setosa": 2, "Iris.vericolor": 3, "Iris.virginica": 4},inplace=True)

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x=pd.DataFrame(df,columns=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalLengthCm"]).values
y=df.Species.values.reshape(-1,1)

# %%
x
# Out:
# array([[5.1, 3.5, 1.4, 1.4],
#        [4.9, 3. , 1.4, 1.4],
#        [4.7, 3.2, 1.3, 1.3],
#        [4.6, 3.1, 1.5, 1.5],
#        [5. , 3.6, 1.4, 1.4],
#        [5.4, 3.9, 1.7, 1.7],
#        [4.6, 3.4, 1.4, 1.4],
#        [5. , 3.4, 1.5, 1.5],
#        [4.4, 2.9, 1.4, 1.4],
#        [4.9, 3.1, 1.5, 1.5],
#        [5.4, 3.7, 1.5, 1.5],
#        [4.8, 3.4, 1.6, 1.6],
#        [4.8, 3. , 1.4, 1.4],
#        [4.3, 3. , 1.1, 1.1],
#        [5.8, 4. , 1.2, 1.2],
#        [5.7, 4.4, 1.5, 1.5],
#        [5.4, 3.9, 1.3, 1.3],
#        [5.1, 3.5, 1.4, 1.4],
#        [5.7, 3.8, 1.7, 1.7],
#        [5.1, 3.8, 1.5, 1.5],
#        [5.4, 3.4, 1.7, 1.7],
#        [5.1, 3.7, 1.5, 1.5],
#        [4.6, 3.6, 1. , 1. ],
#        [5.1, 3.3, 1.7, 1.7],
#        [4.8, 3.4, 1.9, 1.9],
#        [5. , 3. , 1.6, 1.6],
#        [5. , 3.4, 1.6, 1.6],
#        [5.2, 3.5, 1.5, 1.5],
#        [5.2, 3.4, 1.4, 1.4],
#        [4.7, 3.2, 1.6, 1.6],
#        [4.8, 3.1, 1.6, 1.6],
#        [5.4, 3.4, 1.5, 1.5],
# ...

# %%
y
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
k=12
clf=KNeighborsClassifier(k)
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
metrics.accuracy_score=(y_test,y_pred)
